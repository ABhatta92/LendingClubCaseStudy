# %% [markdown]
# # Lending Club EDA

# %%
# Importing required libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
# Reading the data into a Pandas df
df = pd.read_csv("data/loan.csv")
# Out:
# C:\Users\abhir\AppData\Local\Temp\ipykernel_8800\3598531694.py:2: DtypeWarning: Columns (47) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("data/loan.csv")

# %%
# Inspecting the data
df.head()
# Out:
#         id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0  1077501    1296599       5000         5000           4975.0   36 months
# 1  1077430    1314167       2500         2500           2500.0   60 months
# 2  1077175    1313524       2400         2400           2400.0   36 months
# 3  1076863    1277178      10000        10000          10000.0   36 months
# 4  1075358    1311748       3000         3000           3000.0   60 months
#
#   int_rate  installment grade sub_grade  ... num_tl_90g_dpd_24m  \
# 0   10.65%       162.87     B        B2  ...                NaN
# 1   15.27%        59.83     C        C4  ...                NaN
# 2   15.96%        84.33     C        C5  ...                NaN
# 3   13.49%       339.31     C        C1  ...                NaN
# 4   12.69%        67.79     B        B5  ...                NaN
#
#   num_tl_op_past_12m pct_tl_nvr_dlq  percent_bc_gt_75 pub_rec_bankruptcies  \
# 0                NaN            NaN               NaN                  0.0
# 1                NaN            NaN               NaN                  0.0
# 2                NaN            NaN               NaN                  0.0
# 3                NaN            NaN               NaN                  0.0
# 4                NaN            NaN               NaN                  0.0
#
#   tax_liens tot_hi_cred_lim total_bal_ex_mort total_bc_limit  \
# 0       0.0             NaN               NaN            NaN
# 1       0.0             NaN               NaN            NaN
# 2       0.0             NaN               NaN            NaN
# 3       0.0             NaN               NaN            NaN
# 4       0.0             NaN               NaN            NaN
#
#   total_il_high_credit_limit
# 0                        NaN
# 1                        NaN
# 2                        NaN
# 3                        NaN
# 4                        NaN
#
# [5 rows x 111 columns]

# %%
df.shape
# Out:
# (39717, 111)

# %%
# Dropping unnecessary id columns
df.drop(['id', 'member_id'], axis = 1, inplace = True)
df.shape
# Out:
# (39717, 109)

# %% [markdown]
# #### For the purpose of analysis, we will not consider the loans which are still in Current status since we cannot consider them to be either default or not default

# %%
df = df[df['loan_status'] != 'Current']
df.shape
# Out:
# (38577, 109)

# %%
# A function to retrieve the data types for each column in a Pandas DataFrame
def get_data_types(df):
    data_types = {}
    for (col, dtype) in zip(df.columns, df.dtypes):
        data_types[col] = dtype
    
    columns = []
    dtypes = []
    for key,value in data_types.items():
        columns.append(key)
        dtypes.append(value)
    
    data = {"column_name":columns,"data_type":dtypes}
    data_types = pd.DataFrame(data)
    return data_types

# %%
# A function to retrieve the null counts for each column in a Pandas DataFrame
def get_null_counts(df):
    nulls = {}
    for (col, dtype) in zip(df.columns, df.isnull().sum()):
        nulls[col] = dtype

    columns = []
    count_nulls = []
    for key,value in nulls.items():
        columns.append(key)
        count_nulls.append(value)
    data = {"column_name":columns,"count_nulls":count_nulls}
    nulls = pd.DataFrame(data)
    return nulls

# %%
# A funciton to print two values passed as arguments along with the percentage difference between them
def print_vals(x,y):
    print(f"df1:{x}")
    print(f"df2:{y}")
    diff = ((y-x)/x)*100
    print(f"difference = {diff}")

# %%
# A function to compare descriptive stats for the same column in two Pandas DataFrames
def compare_numerical_column(df1, df2, column_name):
    arr1 = np.array(df1[column_name])
    arr2 = np.array(df2[column_name])
    # All value differences are calculated as (((value in df2)-(value in df1))/(value in df1))*100
    print("Min:")
    print_vals(np.min(arr1),np.min(arr2))
    print("Max:")
    print_vals(np.max(arr1),np.max(arr2))
    print("Mean:")
    print_vals(np.mean(arr1),np.mean(arr2))
    print("25th percentile:")
    print_vals(np.percentile(arr1, 25),np.percentile(arr2, 25))
    print("Median:")
    print_vals(np.median(arr1),np.median(arr2))
    print("75th percentile:")
    print_vals(np.percentile(arr1, 75),np.percentile(arr2, 75))

# %%
# A function to plot side by side boxplots and then histograms for the same column in two Pandas DataFrames
def plot_numerical_cols(df1, df2, column_name):
    x = 'loan_status'
    fig, axs = plt.subplots(2, 2, figsize=(12, 8))

    # Side-by-side boxplot
    axs[0, 0].boxplot([df1[column_name], df2[column_name]], patch_artist=True, boxprops=dict(facecolor='lightblue'))
    axs[0, 0].set_xticklabels([f'{df1[x][0]}', f'{df2[x][0]}'])
    axs[0, 0].set_ylabel(column_name)
    axs[0, 0].set_title('Side-by-Side Boxplot')

    axs[1, 0].hist(df1[column_name], bins=10, alpha=0.5, color='skyblue', label=f'Histogram ({df1[x][0]})')
    axs[1, 0].set_xlabel(column_name)
    axs[1, 0].set_ylabel('Frequency')
    axs[1, 0].set_title(f"{df1[x][0]}")

    axs[1, 1].hist(df2[column_name], bins=10, alpha=0.5, color='lightgreen', label=f'Histogram ({df2[x][0]})')
    axs[1, 1].set_xlabel(column_name)
    axs[1, 1].set_ylabel('Frequency')
    axs[1, 1].set_title(f"{df2[x][0]}")

    plt.subplots_adjust(hspace=0.3, wspace=0.3)
    plt.show()

# %%
# A function to remove outliers from a numerical column
# Outliers are defined as values lying outside -3 standard deviations to +3 standard deviations from the mean
def remove_outliers(df,col):
    arr = np.array(df[col])
    mean = np.mean(arr)
    std = np.std(arr)
    df = df[(df[col] <= mean+(3*std)) & (df[col >= mean-(3*std)])]
    return df

# %%
def get_metadata(df):
    data_types = get_data_types(df)
    nulls = get_null_counts(df)
    df_metadata = pd.merge(data_types,nulls, on = 'column_name', how = 'inner')
    return df_metadata

# %% [markdown]
# #### Discovering and dealing with null/missing values

# %%
df_metadata = get_metadata(df)

# %%
# Calculating percentage of missing values
df_metadata['null_percentage'] = (df_metadata['count_nulls']/df.shape[0])*100

# %%
df_metadata['null_percentage'].value_counts()
# Out:
# 100.000000    55
# 0.000000      41
# 0.145164       2
# 6.185033       1
# 2.677761       1
# 32.472717      1
# 0.028514       1
# 64.559193      1
# 92.897322      1
# 0.129611       1
# 0.184047       1
# 0.005184       1
# 1.806776       1
# 0.101097       1
# Name: null_percentage, dtype: int64

# %%
df_metadata
# Out:
#                         column_name data_type  count_nulls  null_percentage
# 17                             desc    object        12527        32.472717
# 26           mths_since_last_delinq   float64        24905        64.559193
# 27           mths_since_last_record   float64        35837        92.897322
# 45                     next_pymnt_d    object        38577       100.000000
# 48      mths_since_last_major_derog   float64        38577       100.000000
# 51                 annual_inc_joint   float64        38577       100.000000
# 52                        dti_joint   float64        38577       100.000000
# 53        verification_status_joint   float64        38577       100.000000
# 55                     tot_coll_amt   float64        38577       100.000000
# 56                      tot_cur_bal   float64        38577       100.000000
# 57                      open_acc_6m   float64        38577       100.000000
# 58                       open_il_6m   float64        38577       100.000000
# 59                      open_il_12m   float64        38577       100.000000
# 60                      open_il_24m   float64        38577       100.000000
# 61               mths_since_rcnt_il   float64        38577       100.000000
# 62                     total_bal_il   float64        38577       100.000000
# 63                          il_util   float64        38577       100.000000
# 64                      open_rv_12m   float64        38577       100.000000
# 65                      open_rv_24m   float64        38577       100.000000
# 66                       max_bal_bc   float64        38577       100.000000
# 67                         all_util   float64        38577       100.000000
# 68                 total_rev_hi_lim   float64        38577       100.000000
# 69                           inq_fi   float64        38577       100.000000
# 70                      total_cu_tl   float64        38577       100.000000
# 71                     inq_last_12m   float64        38577       100.000000
# 72             acc_open_past_24mths   float64        38577       100.000000
# 73                      avg_cur_bal   float64        38577       100.000000
# 74                   bc_open_to_buy   float64        38577       100.000000
# 75                          bc_util   float64        38577       100.000000
# 78               mo_sin_old_il_acct   float64        38577       100.000000
# 79             mo_sin_old_rev_tl_op   float64        38577       100.000000
# 80            mo_sin_rcnt_rev_tl_op   float64        38577       100.000000
# 81                   mo_sin_rcnt_tl   float64        38577       100.000000
# 82                         mort_acc   float64        38577       100.000000
# 83             mths_since_recent_bc   float64        38577       100.000000
# 84         mths_since_recent_bc_dlq   float64        38577       100.000000
# 85            mths_since_recent_inq   float64        38577       100.000000
# 86   mths_since_recent_revol_delinq   float64        38577       100.000000
# 87            num_accts_ever_120_pd   float64        38577       100.000000
# 88                   num_actv_bc_tl   float64        38577       100.000000
# 89                  num_actv_rev_tl   float64        38577       100.000000
# 90                      num_bc_sats   float64        38577       100.000000
# 91                        num_bc_tl   float64        38577       100.000000
# 92                        num_il_tl   float64        38577       100.000000
# 93                    num_op_rev_tl   float64        38577       100.000000
# 94                    num_rev_accts   float64        38577       100.000000
# 95              num_rev_tl_bal_gt_0   float64        38577       100.000000
# 96                         num_sats   float64        38577       100.000000
# 97                 num_tl_120dpd_2m   float64        38577       100.000000
# 98                     num_tl_30dpd   float64        38577       100.000000
# 99               num_tl_90g_dpd_24m   float64        38577       100.000000
# 100              num_tl_op_past_12m   float64        38577       100.000000
# 101                  pct_tl_nvr_dlq   float64        38577       100.000000
# 102                percent_bc_gt_75   float64        38577       100.000000
# 105                 tot_hi_cred_lim   float64        38577       100.000000
# 106               total_bal_ex_mort   float64        38577       100.000000
# 107                  total_bc_limit   float64        38577       100.000000
# 108      total_il_high_credit_limit   float64        38577       100.000000

# %%
# If a column has 10% or more of it's values missing, replacing them may skew the data and, therefore, the column is dropped
df_metadata = df_metadata[df_metadata['null_percentage'] >= 10]

# %%
columns_to_remove = df_metadata['column_name'].to_list()
len(columns_to_remove)
# Out:
# 58

# %%
df.drop(columns_to_remove, axis = 1, inplace = True)
df.shape
# Out:
# (38577, 51)

# %%
df_metadata = get_metadata(df)

# %%
df_metadata
# Out:
#                    column_name data_type  count_nulls
# 0                    loan_amnt     int64            0
# 1                  funded_amnt     int64            0
# 2              funded_amnt_inv   float64            0
# 3                         term    object            0
# 4                     int_rate    object            0
# 5                  installment   float64            0
# 6                        grade    object            0
# 7                    sub_grade    object            0
# 8                    emp_title    object         2386
# 9                   emp_length    object         1033
# 10              home_ownership    object            0
# 11                  annual_inc   float64            0
# 12         verification_status    object            0
# 13                     issue_d    object            0
# 14                 loan_status    object            0
# 15                  pymnt_plan    object            0
# 16                         url    object            0
# 17                     purpose    object            0
# 18                       title    object           11
# 19                    zip_code    object            0
# 20                  addr_state    object            0
# 21                         dti   float64            0
# 22                 delinq_2yrs     int64            0
# 23            earliest_cr_line    object            0
# 24              inq_last_6mths     int64            0
# 25                    open_acc     int64            0
# 26                     pub_rec     int64            0
# 27                   revol_bal     int64            0
# 28                  revol_util    object           50
# 29                   total_acc     int64            0
# 30         initial_list_status    object            0
# 31                   out_prncp   float64            0
# 32               out_prncp_inv   float64            0
# 33                 total_pymnt   float64            0
# 34             total_pymnt_inv   float64            0
# 35             total_rec_prncp   float64            0
# 36               total_rec_int   float64            0
# 37          total_rec_late_fee   float64            0
# 38                  recoveries   float64            0
# 39     collection_recovery_fee   float64            0
# 40                last_pymnt_d    object           71
# 41             last_pymnt_amnt   float64            0
# 42          last_credit_pull_d    object            2
# 43  collections_12_mths_ex_med   float64           56
# 44                 policy_code     int64            0
# 45            application_type    object            0
# 46              acc_now_delinq     int64            0
# 47    chargeoff_within_12_mths   float64           56
# 48                 delinq_amnt     int64            0
# 49        pub_rec_bankruptcies   float64          697
# 50                   tax_liens   float64           39

# %%
df_metadata['data_type'].value_counts()
# Out:
# object     22
# float64    18
# int64      11
# Name: data_type, dtype: int64

# %%
numeric = df_metadata[df_metadata['data_type'] != 'object']
non_numeric = df_metadata[df_metadata['data_type'] == 'object']

# %%
numeric_cols = numeric['column_name'].to_list()
len(numeric_cols)
# Out:
# 29

# %%
non_numeric_cols = non_numeric['column_name'].to_list()
len(non_numeric_cols)
# Out:
# 22

# %%
df_obj = df[non_numeric_cols]

# %%
df_obj.head(10)
# Out:
#           term int_rate grade sub_grade                            emp_title  \
# 1    60 months   15.27%     C        C4                                Ryder
# 3    36 months   13.49%     C        C1                  AIR RESOURCES BOARD
# 5    36 months    7.90%     A        A4                 Veolia Transportaton
# 6    60 months   15.96%     C        C5            Southern Star Photography
# 7    36 months   18.64%     E        E1                      MKC Accounting
# 9    60 months   12.69%     B        B5                            Starbucks
# 10   60 months   14.65%     C        C3                Southwest Rural metro
# 11   36 months   12.69%     B        B5                                 UCLA
# 12   36 months   13.49%     C        C1  Va. Dept of Conservation/Recreation
# 13   36 months    9.91%     B        B1                               Target
#
#    emp_length home_ownership verification_status issue_d  loan_status  ...  \
# 1    < 1 year           RENT     Source Verified  Dec-11  Charged Off  ...
# 3   10+ years           RENT     Source Verified  Dec-11   Fully Paid  ...
# 5     3 years           RENT     Source Verified  Dec-11   Fully Paid  ...
# 6     8 years           RENT        Not Verified  Dec-11   Fully Paid  ...
# 7     9 years           RENT     Source Verified  Dec-11   Fully Paid  ...
# 9    < 1 year           RENT            Verified  Dec-11  Charged Off  ...
# 10    5 years            OWN        Not Verified  Dec-11   Fully Paid  ...
# 11  10+ years            OWN     Source Verified  Dec-11   Fully Paid  ...
# 12   < 1 year           RENT     Source Verified  Dec-11  Charged Off  ...
# 13    3 years           RENT     Source Verified  Dec-11   Fully Paid  ...
#
#                purpose                                  title zip_code  \
# 1                  car                                   bike    309xx
# 3                other                               personel    917xx
# 5              wedding  My wedding loan I promise to pay back    852xx
# 6   debt_consolidation                                   Loan    280xx
# 7                  car                        Car Downpayment    900xx
# 9                other            Building my credit history.    774xx
# 10  debt_consolidation             High intrest Consolidation    853xx
# 11  debt_consolidation                          Consolidation    913xx
# 12  debt_consolidation                                freedom    245xx
# 13         credit_card                          citicard fund    606xx
#
#    addr_state earliest_cr_line revol_util initial_list_status last_pymnt_d  \
# 1          GA           Apr-99      9.40%                   f       Apr-13
# 3          CA           Feb-96        21%                   f       Jan-15
# 5          AZ           Nov-04     28.30%                   f       Jan-15
# 6          NC           Jul-05     85.60%                   f       May-16
# 7          CA           Jan-07     87.50%                   f       Jan-15
# 9          TX           Sep-04     36.50%                   f       Nov-12
# 10         AZ           Jan-98     20.60%                   f       Jun-13
# 11         CA           Oct-89     67.10%                   f       Sep-13
# 12         VA           Apr-04     91.70%                   f       Jul-12
# 13         IL           Jul-03     43.10%                   f       Jan-15
#
#    last_credit_pull_d application_type
# 1              Sep-13       INDIVIDUAL
# 3              Apr-16       INDIVIDUAL
# 5              Jan-16       INDIVIDUAL
# 6              May-16       INDIVIDUAL
# 7              Dec-14       INDIVIDUAL
# 9              Mar-13       INDIVIDUAL
# 10             Dec-15       INDIVIDUAL
# 11             Aug-13       INDIVIDUAL
# 12             Nov-12       INDIVIDUAL
# 13             May-16       INDIVIDUAL
#
# [10 rows x 22 columns]

# %%
df['emp_title'].value_counts()
# Out:
# US Army                                     131
# Bank of America                             107
# IBM                                          65
# AT&T                                         57
# Kaiser Permanente                            56
#                                            ...
# amneal pharmaceuticals                        1
# Net Equity Financial                          1
# Kernersville Fire Department                  1
# The Keith Corp. (empl by county, now Kei      1
# Evergreen Center                              1
# Name: emp_title, Length: 28027, dtype: int64

# %%
"""
If we replace the missing values with the mode for emp_title, the frequency of the mode will increase from 131 to 2517
This could potentially lead to incorrect insights. Therefore, we will be dropping the missing values for emp_title.
"""
df.dropna(subset=['emp_title'], inplace = True)

# %%
df_metadata = get_metadata(df)
df_metadata
# Out:
#                    column_name data_type  count_nulls
# 0                    loan_amnt     int64            0
# 1                  funded_amnt     int64            0
# 2              funded_amnt_inv   float64            0
# 3                         term    object            0
# 4                     int_rate    object            0
# 5                  installment   float64            0
# 6                        grade    object            0
# 7                    sub_grade    object            0
# 8                    emp_title    object            0
# 9                   emp_length    object           55
# 10              home_ownership    object            0
# 11                  annual_inc   float64            0
# 12         verification_status    object            0
# 13                     issue_d    object            0
# 14                 loan_status    object            0
# 15                  pymnt_plan    object            0
# 16                         url    object            0
# 17                     purpose    object            0
# 18                       title    object            9
# 19                    zip_code    object            0
# 20                  addr_state    object            0
# 21                         dti   float64            0
# 22                 delinq_2yrs     int64            0
# 23            earliest_cr_line    object            0
# 24              inq_last_6mths     int64            0
# 25                    open_acc     int64            0
# 26                     pub_rec     int64            0
# 27                   revol_bal     int64            0
# 28                  revol_util    object           46
# 29                   total_acc     int64            0
# 30         initial_list_status    object            0
# 31                   out_prncp   float64            0
# 32               out_prncp_inv   float64            0
# 33                 total_pymnt   float64            0
# 34             total_pymnt_inv   float64            0
# 35             total_rec_prncp   float64            0
# 36               total_rec_int   float64            0
# 37          total_rec_late_fee   float64            0
# 38                  recoveries   float64            0
# 39     collection_recovery_fee   float64            0
# 40                last_pymnt_d    object           64
# 41             last_pymnt_amnt   float64            0
# 42          last_credit_pull_d    object            0
# 43  collections_12_mths_ex_med   float64           47
# 44                 policy_code     int64            0
# 45            application_type    object            0
# 46              acc_now_delinq     int64            0
# 47    chargeoff_within_12_mths   float64           47
# 48                 delinq_amnt     int64            0
# 49        pub_rec_bankruptcies   float64          654
# 50                   tax_liens   float64           32

# %%
df['emp_length'].value_counts()

# %%
# For emp_length we can impute with the mode
df['emp_length'].fillna('10+ years', inplace = True)

# %%
# Converting date columns to datetime format
df['issue_d'] = pd.to_datetime(df['issue_d'], format='%b-%y')
df['last_pymnt_d'] = pd.to_datetime(df['last_pymnt_d'], format='%b-%y')
df['last_credit_pull_d'] = pd.to_datetime(df['last_credit_pull_d'], format='%b-%y')

# %%
df['collections_12_mths_ex_med'].value_counts()

# %%
# For the next two columns, since all the values are 0.0 except for Nulls, we can replace the nulls with 0.0
df['collections_12_mths_ex_med'].fillna(0.0, inplace = True)
df['chargeoff_within_12_mths'].fillna(0.0, inplace = True)

# %%
df['title'].value_counts()

# %%
# Since the number of missing values in title is very smmall, we can replace it with the mode
df['title'].fillna('Debt Consolidation', inplace = True)

# %%
df['revol_util'].value_counts()

# %%
df['chargeoff_within_12_mths'].value_counts()

# %%
df_dflt = df[df['loan_status'] == 'Charged Off']
df_dflt.reset_index(inplace=True)
df_dflt.drop('index', axis = 1, inplace = True)
df_dflt.shape

# %%
df_not_dflt = df[df['loan_status'] != 'Charged Off']
df_not_dflt.reset_index(inplace=True)
df_not_dflt.drop('index', axis = 1, inplace = True)
df_not_dflt.shape

# %%
for col in numeric_cols:
    remove_outliers(df_dflt, col)
    remove_outliers(df_not_dflt, col)

# %%
for col in numeric_cols:
    print(f"Descriptive Stats for {col}")
    compare_numerical_column(df_dflt,df_not_dflt, col)
    print(f"Plots for {col}")
    plot_numerical_cols(df_dflt,df_not_dflt, col)

# %%
df_dflt.head()

# %%
df_dflt.describe()

# %%
dflt_dtypes = get_data_types(df_dflt)

# %%
non_dflt_dtypes = get_data_types(df_not_dflt)

# %%
df_dflt.isnull().sum()

# %%
df_dflt['emp_title'].value_counts()

# %%
df_dflt['emp_length'].value_counts()

# %%
df_dflt['pub_rec_bankruptcies'].value_counts()

# %%
df_not_dflt.isnull().sum()

# %%
data_types = get_data_types(df)

# %%
numeric_cols = data_types[data_types['data_type'] != 'object']

# %%
len(numeric_cols)
